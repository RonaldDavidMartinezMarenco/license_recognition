# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !scp '/content/gdrive/My Drive/Yolov11ObjectDetection/License Plate Recognition.v6i.yolov11.zip' '/content/data.zip'

# !unzip '/content/data.zip' -d '/content/'
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   inflating: /content/train/labels/xemay2283_jpg.rf.595548b042f4dae3803e619e53440cc7.txt
#   inflating: /content/train/labels/xemay2284_jpg.rf.368af2a4409000b4e6f6f1479098ecbf.txt
#   inflating: /content/train/labels/xemay2285_jpg.rf.3c526d0ff3d3789263e2a9fd67459af5.txt
#   inflating: /content/train/labels/xemay2286_jpg.rf.4bb76895d893c7f970dfee99333b911b.txt
#   inflating: /content/train/labels/xemay2287_jpg.rf.cafbabfe2cadb338caffebf5e46a5f84.txt
#   inflating: /content/train/labels/xemay2288_jpg.rf.ce56893342bcc0e35d67f52d89b8c8e2.txt
#   inflating: /content/train/labels/xemay2289_jpg.rf.60c50987982c2a671c966c49c28ca531.txt
#   inflating: /content/train/labels/xemay228_jpg.rf.2ccfe0b9ff1f874029a6291aef0a3eac.txt
#   inflating: /content/train/labels/xemay2291_jpg.rf.f859460b5c6ae6c1a2033f91ca3fadd4.txt
#   inflating: /content/train/labels/xemay2292_jpg.rf.d15803966b2f54dc0b39f39427374fc1.txt
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.6/922.6 kB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 114.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import os

from ultralytics import YOLO


config_path = 'data.yaml'

# Load a model
model = YOLO("yolo11n.pt").to("cuda")  # load pre trained model

# Use the model
model.train(data=config_path, epochs=20)  # train the model
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 86.4MB/s]
# ...
